# %% [markdown]
# # CusomMLP

# %%
# !python ../template/main.py
# Out:
# -----------------------------------------------1--------------------------------------------
# Train Loss : 0.005, Train Accuracy : 0.89087, Test Loss : 0.002, Test Accuracy : 0.95330
# -----------------------------------------------2--------------------------------------------
# Train Loss : 0.002, Train Accuracy : 0.95715, Test Loss : 0.002, Test Accuracy : 0.96090
# -----------------------------------------------3--------------------------------------------
# Train Loss : 0.002, Train Accuracy : 0.96872, Test Loss : 0.001, Test Accuracy : 0.97030
# -----------------------------------------------4--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.97485, Test Loss : 0.001, Test Accuracy : 0.97250
# -----------------------------------------------5--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.97953, Test Loss : 0.002, Test Accuracy : 0.97170
# ...

# %% [markdown]
# # LeNet5

# %%
# !python ../template/main.py
# Out:
# -----------------------------------------------1--------------------------------------------
# Train Loss : 0.005, Train Accuracy : 0.89443, Test Loss : 0.001, Test Accuracy : 0.97660
# -----------------------------------------------2--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.97837, Test Loss : 0.001, Test Accuracy : 0.98320
# -----------------------------------------------3--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.98403, Test Loss : 0.001, Test Accuracy : 0.97970
# -----------------------------------------------4--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.98822, Test Loss : 0.001, Test Accuracy : 0.98740
# -----------------------------------------------5--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.99000, Test Loss : 0.001, Test Accuracy : 0.98720
# ...

# %% [markdown]
# # Custom LeNet5

# %%
# !python ../template/main.py
# Out:
# -----------------------------------------------1--------------------------------------------
# Train Loss : 0.007, Train Accuracy : 0.86033, Test Loss : 0.001, Test Accuracy : 0.96970
# -----------------------------------------------2--------------------------------------------
# Train Loss : 0.002, Train Accuracy : 0.96400, Test Loss : 0.001, Test Accuracy : 0.98270
# -----------------------------------------------3--------------------------------------------
# Train Loss : 0.002, Train Accuracy : 0.97202, Test Loss : 0.001, Test Accuracy : 0.98420
# -----------------------------------------------4--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.97700, Test Loss : 0.001, Test Accuracy : 0.98410
# -----------------------------------------------5--------------------------------------------
# Train Loss : 0.001, Train Accuracy : 0.97903, Test Loss : 0.001, Test Accuracy : 0.98460
# ...
