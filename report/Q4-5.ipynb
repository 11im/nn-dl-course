# %% [markdown]
# # Q4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## CustomMLP Plot

# %%
MLP_train_loss_path = "../result/CustomMLP/train_loss.npy"
MLP_train_accuracy_path = "../result/CustomMLP/train_accuracy.npy"
MLP_test_loss_path = "../result/CustomMLP/test_loss.npy"
MLP_test_accuracy_path = "../result/CustomMLP/test_accuracy.npy"

MLP_train_loss = np.load(MLP_train_loss_path)
MLP_train_accuracy = np.load(MLP_train_accuracy_path)
MLP_test_loss = np.load(MLP_test_loss_path)
MLP_test_accuracy = np.load(MLP_test_accuracy_path)

epochs = len(train_loss)

plt.figure(figsize=(9, 6))

# Loss Plot
plt.subplot(2, 2, 1)
plt.plot(range(epochs), MLP_train_loss, label="Train Loss")
plt.title("Train Loss")
plt.xlabel("Epoch")
# plt.ylabel("Loss")
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(range(epochs), MLP_test_loss, label="Test Loss")
plt.title("Test Loss")
plt.xlabel("Epoch")
# plt.ylabel("Loss")
plt.legend()

# Accuracy Plot
plt.subplot(2, 2, 3)
plt.plot(range(epochs), MLP_train_accuracy, label="Train Accuracy")
plt.title("Train Accuracy")
plt.xlabel("Epoch")
# plt.ylabel("Accuracy")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(range(epochs), MLP_test_accuracy, label="Test Accuracy")
plt.title("Test Accuracy")
plt.xlabel("Epoch")
# plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## LeNet

# %%
LeNet_train_loss_path = "../result/LeNet/train_loss.npy"
LeNet_train_accuracy_path = "../result/LeNet/train_accuracy.npy"
LeNet_test_loss_path = "../result/LeNet/test_loss.npy"
LeNet_test_accuracy_path = "../result/LeNet/test_accuracy.npy"

LeNet_train_loss = np.load(LeNet_train_loss_path)
LeNet_train_accuracy = np.load(LeNet_train_accuracy_path)
LeNet_test_loss = np.load(LeNet_test_loss_path)
LeNet_test_accuracy = np.load(LeNet_test_accuracy_path)

epochs = len(train_loss)

plt.figure(figsize=(9, 6))

# Loss Plot
plt.subplot(2, 2, 1)
plt.plot(range(epochs), LeNet_train_loss, label="Train Loss")
plt.title("Train Loss")
plt.xlabel("Epoch")
# plt.ylabel("Loss")
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(range(epochs), LeNet_test_loss, label="Test Loss")
plt.title("Test Loss")
plt.xlabel("Epoch")
# plt.ylabel("Loss")
plt.legend()

# Accuracy Plot
plt.subplot(2, 2, 3)
plt.plot(range(epochs), LeNet_train_accuracy, label="Train Accuracy")
plt.title("Train Accuracy")
plt.xlabel("Epoch")
# plt.ylabel("Accuracy")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(range(epochs), LeNet_test_accuracy, label="Test Accuracy")
plt.title("Test Accuracy")
plt.xlabel("Epoch")
# plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Q5

# %%
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 2)
plt.plot(range(epochs), LeNet_test_loss, label="LeNet Test Loss")
plt.plot(range(epochs), MLP_train_loss, label="CustomMLP Train Loss")
plt.title("Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(range(epochs), LeNet_test_accuracy, label="LeNet Test Accuracy")
plt.plot(range(epochs), MLP_test_accuracy, label="CustomMLP Test Accuracy")
plt.title("Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q5-1. Compare the predictive performance
# A. LeNet-5 model shows much less Loss and higher Accuracy than my CustomMLP model
# ### Q5-2. Make sure that the accuracy of LeNet-5 (your implementation) is similar to the known accuracy.
# A. Known accuracy of Lenet-5 model is about 95~98% and my implementation shows similar result.
